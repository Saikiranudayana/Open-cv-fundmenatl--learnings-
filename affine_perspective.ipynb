# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('giraffe.jpg')
imag_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

plt.imshow(imag_rgb)

# %%
rows,cols,_ = imag_rgb.shape

# %%
input_points = np.float32([[50,50],[cols-50,50],[50,rows-50],[cols-50,rows-50]])

output_points = np.float32([[100,100],[cols-100,50],[50,rows-100],[cols-100,rows-100]])


m = cv2.getPerspectiveTransform(input_points,output_points)
print(m)
# Out:
# [[ 6.33165996e-01 -1.01854998e-01  7.09351472e+01]
#  [-1.34137025e-01  6.57474014e-01  7.13338477e+01]
#  [-2.45223081e-04 -2.54637496e-04  1.00000000e+00]]

# %%
prespective_image = cv2.warpPerspective(imag_rgb,m,(cols,rows))

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)

plt.imshow(imag_rgb)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(prespective_image)
plt.title('Perspective Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(499.5), np.float64(646.5), np.float64(-0.5))

# %%
##Affine transformation


input_points = np.float32([[50,50],[200,50],[50,200]])
output_points = np.float32([[10,100],[200,50],[100,250]])



n = cv2.getAffineTransform(input_points,output_points)
prespective_image = cv2.warpAffine(imag_rgb,n,(cols,rows))
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)

plt.imshow(imag_rgb)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(prespective_image)
plt.title('Perspective Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(499.5), np.float64(646.5), np.float64(-0.5))
